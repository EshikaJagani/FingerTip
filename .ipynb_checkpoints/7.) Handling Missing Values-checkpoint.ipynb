# %%
import pandas as pd

# %%
data=pd.read_csv("Missing_Values.csv",
                parse_dates=["Date"])
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02   NaN    9.0    Tuesday
# 2 2019-01-10  28.0    NaN  Wednesday
# 3 2019-01-11  32.0    7.0        NaN
# 4 2019-01-12   NaN    NaN     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17   NaN    NaN        NaN
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
data.dtypes
# Out:
# Date     datetime64[ns]
# Age             float64
# Sales           float64
# Day              object
# dtype: object

# %%
data.set_index("Date", inplace=True)
data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02   NaN    9.0    Tuesday
# 2019-01-10  28.0    NaN  Wednesday
# 2019-01-11  32.0    7.0        NaN
# 2019-01-12   NaN    NaN     Monday
# 2019-01-16  32.0    NaN    Tuesday
# 2019-01-17   NaN    NaN        NaN
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
data.loc["2019-01-01"],["Age"]
# Out:
# (Age        32.0
#  Sales       6.0
#  Day      Monday
#  Name: 2019-01-01 00:00:00, dtype: object,
#  ['Age'])

# %%
data.iloc[0],[0]
# Out:
# (Age        32.0
#  Sales       6.0
#  Day      Monday
#  Name: 2019-01-01 00:00:00, dtype: object,
#  [0])

# %%
# Convert date from str to timestamp

# %%
#check data type of day column for 0 index
type(data.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#to convert day str type to date(timestamp) type
data=pd.read_csv("Missing_Values.csv",parse_dates=["Date"])

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02   NaN    9.0    Tuesday
# 2 2019-01-10  28.0    NaN  Wednesday
# 3 2019-01-11  32.0    7.0        NaN
# 4 2019-01-12   NaN    NaN     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17   NaN    NaN        NaN
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
#set day as index(Inplace =True is important else it will 
# not modify the original dataframe instead it will return new dataframe)
data.set_index('Date',inplace=True)

# %%
data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02   NaN    9.0    Tuesday
# 2019-01-10  28.0    NaN  Wednesday
# 2019-01-11  32.0    7.0        NaN
# 2019-01-12   NaN    NaN     Monday
# 2019-01-16  32.0    NaN    Tuesday
# 2019-01-17   NaN    NaN        NaN
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
data=pd.read_csv("Missing_Values.csv",parse_dates=["Date"])

# %%
x=data

# %%
data.set_index('Date',inplace=True)

# %%
x.reset_index()
x
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02   NaN    9.0    Tuesday
# 2019-01-10  28.0    NaN  Wednesday
# 2019-01-11  32.0    7.0        NaN
# 2019-01-12   NaN    NaN     Monday
# 2019-01-16  32.0    NaN    Tuesday
# 2019-01-17   NaN    NaN        NaN
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
data.set_index('Date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21776/2086312366.py in <module>
# ----> 1 data.set_index('Date', inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
data.reset_index()
print(data)
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02   NaN    9.0    Tuesday
# 2019-01-10  28.0    NaN  Wednesday
# 2019-01-11  32.0    7.0        NaN
# 2019-01-12   NaN    NaN     Monday
# 2019-01-16  32.0    NaN    Tuesday
# 2019-01-17   NaN    NaN        NaN
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02   NaN    9.0    Tuesday
# 2019-01-10  28.0    NaN  Wednesday
# 2019-01-11  32.0    7.0        NaN
# 2019-01-12   NaN    NaN     Monday
# 2019-01-16  32.0    NaN    Tuesday
# 2019-01-17   NaN    NaN        NaN
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
data.loc['2019-01-01','Age']
# Out:
# 32.0

# %%
data.iloc[0,0]
# Out:
# 32.0

# %%
data.reset_index()
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02   NaN    9.0    Tuesday
# 2 2019-01-10  28.0    NaN  Wednesday
# 3 2019-01-11  32.0    7.0        NaN
# 4 2019-01-12   NaN    NaN     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17   NaN    NaN        NaN
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# # Replace NaN Values with zero

# %%
data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02   NaN    9.0    Tuesday
# 2019-01-10  28.0    NaN  Wednesday
# 2019-01-11  32.0    7.0        NaN
# 2019-01-12   NaN    NaN     Monday
# 2019-01-16  32.0    NaN    Tuesday
# 2019-01-17   NaN    NaN        NaN
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
# replace NaN with 0
new_data=data.fillna(0)
new_data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02   0.0    9.0    Tuesday
# 2019-01-10  28.0    0.0  Wednesday
# 2019-01-11  32.0    7.0          0
# 2019-01-12   0.0    0.0     Monday
# 2019-01-16  32.0    0.0    Tuesday
# 2019-01-17   0.0    0.0          0
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
a=data
a
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02   NaN    9.0    Tuesday
# 2019-01-10  28.0    NaN  Wednesday
# 2019-01-11  32.0    7.0        NaN
# 2019-01-12   NaN    NaN     Monday
# 2019-01-16  32.0    NaN    Tuesday
# 2019-01-17   NaN    NaN        NaN
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
a=a["Age"].fillna(35)
a
# Out:
# Date
# 2019-01-01    32.0
# 2019-01-02    35.0
# 2019-01-10    28.0
# 2019-01-11    32.0
# 2019-01-12    35.0
# 2019-01-16    32.0
# 2019-01-17    35.0
# 2019-01-20    34.0
# 2019-01-21    40.0
# Name: Age, dtype: float64

# %% [markdown]
# When we want to replace NaN with specific value in specific column,create a Dictionary for fillna method

# %% [markdown]
# # Filling null values with a single value

# %%
a={
        'Age': 10,
        'Sales': 100,
        'Day': 'no Day'
    }

# %%
#pass a dictionary to replace Null,Day can't be replace with 0 so we are 
# replacing this with zero event
new_data = data.fillna(a)
new_data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02  10.0    9.0    Tuesday
# 2019-01-10  28.0  100.0  Wednesday
# 2019-01-11  32.0    7.0     no Day
# 2019-01-12  10.0  100.0     Monday
# 2019-01-16  32.0  100.0    Tuesday
# 2019-01-17  10.0  100.0     no Day
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02   NaN    9.0    Tuesday
# 2019-01-10  28.0    NaN  Wednesday
# 2019-01-11  32.0    7.0        NaN
# 2019-01-12   NaN    NaN     Monday
# 2019-01-16  32.0    NaN    Tuesday
# 2019-01-17   NaN    NaN        NaN
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
# filling null values using fillna()  
data["Sales"].fillna(5000)
# Out:
# Date
# 2019-01-01       6.0
# 2019-01-02       9.0
# 2019-01-10    5000.0
# 2019-01-11       7.0
# 2019-01-12    5000.0
# 2019-01-16    5000.0
# 2019-01-17    5000.0
# 2019-01-20       8.0
# 2019-01-21      12.0
# Name: Sales, dtype: float64

# %% [markdown]
# Estimation for Sales and other column, carry forward the same value by **Forward fill** method

# %% [markdown]
# #  Filling null values with the previous ones

# %%
data=pd.read_csv("Missing_Values.csv",parse_dates=["Date"])
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02   NaN    9.0    Tuesday
# 2 2019-01-10  28.0    NaN  Wednesday
# 3 2019-01-11  32.0    7.0        NaN
# 4 2019-01-12   NaN    NaN     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17   NaN    NaN        NaN
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
#Replace NaN with Forward fill
new_data = data.fillna(method="ffill") 
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    9.0  Wednesday
# 3 2019-01-11  32.0    7.0  Wednesday
# 4 2019-01-12  32.0    7.0     Monday
# 5 2019-01-16  32.0    7.0    Tuesday
# 6 2019-01-17  32.0    7.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# Filling null value with the next ones using **Backward fill** method

# %% [markdown]
# # Backward fill to carry forward next day's value

# %%
#Replace NaN with Backward fill
new_data = data.fillna(method="bfill")
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  28.0    9.0    Tuesday
# 2 2019-01-10  28.0    7.0  Wednesday
# 3 2019-01-11  32.0    7.0     Monday
# 4 2019-01-12  32.0    8.0     Monday
# 5 2019-01-16  32.0    8.0    Tuesday
# 6 2019-01-17  34.0    8.0   Thrusday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# Using **Axis** to fill value horizontally i.e from the neighbouring cell

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02   NaN    9.0    Tuesday
# 2 2019-01-10  28.0    NaN  Wednesday
# 3 2019-01-11  32.0    7.0        NaN
# 4 2019-01-12   NaN    NaN     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17   NaN    NaN        NaN
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
#Fill values by side of the columns (which in our case is not helpful)
new_data = data.fillna(method="bfill",axis="columns")
new_data
# Out:
#         Date     Age      Sales        Day
# 0 2019-01-01    32.0        6.0     Monday
# 1 2019-01-02     9.0        9.0    Tuesday
# 2 2019-01-10    28.0  Wednesday  Wednesday
# 3 2019-01-11    32.0        7.0        NaN
# 4 2019-01-12  Monday     Monday     Monday
# 5 2019-01-16    32.0    Tuesday    Tuesday
# 6 2019-01-17     NaT        NaT        NaT
# 7 2019-01-20    34.0        8.0   Thrusday
# 8 2019-01-21    40.0       12.0    Tuesday

# %% [markdown]
# **Limit** is used to fill multiple consecutive NaN values by limiting the ffill/bfill from previous/next cell not to all, i.e. limit 1 upto 1 cell, limit 2 upto 2 cell

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02   NaN    9.0    Tuesday
# 2 2019-01-10  28.0    NaN  Wednesday
# 3 2019-01-11  32.0    7.0        NaN
# 4 2019-01-12   NaN    NaN     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17   NaN    NaN        NaN
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
new_data = data.fillna(method="ffill",limit=1)
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    9.0  Wednesday
# 3 2019-01-11  32.0    7.0  Wednesday
# 4 2019-01-12  32.0    7.0     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17  32.0    NaN    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
new_data = data.fillna(method="ffill",limit=3)
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    9.0  Wednesday
# 3 2019-01-11  32.0    7.0  Wednesday
# 4 2019-01-12  32.0    7.0     Monday
# 5 2019-01-16  32.0    7.0    Tuesday
# 6 2019-01-17  32.0    7.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
# To check if Nan values are available in data

# %%
data.isnull().mean() *100
# Out:
# Date      0.000000
# Age      33.333333
# Sales    44.444444
# Day      22.222222
# dtype: float64

# %%
# how many na values in each column

# %%
data.isnull().sum()
# Out:
# Date     0
# Age      3
# Sales    4
# Day      2
# dtype: int64

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02   NaN    9.0    Tuesday
# 2 2019-01-10  28.0    NaN  Wednesday
# 3 2019-01-11  32.0    7.0        NaN
# 4 2019-01-12   NaN    NaN     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17   NaN    NaN        NaN
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
# Replace the missing values in the wih Mean value

# %%
a= data['Day'].mode()[0]
a
# Out:
# 'Tuesday'

# %%
data['Day'] = data['Day'].fillna(a)

# %%
#try
#data['Sales'] = data['Sales'].fillna(data['Sales'].median())

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02   NaN    9.0    Tuesday
# 2 2019-01-10  28.0    NaN  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12   NaN    NaN     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17   NaN    NaN    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
# Replace the missing values in the Day Column Removed wih Mode value

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02   NaN    9.0    Tuesday
# 2 2019-01-10  28.0    NaN  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12   NaN    NaN     Monday
# 5 2019-01-16  32.0    NaN    Tuesday
# 6 2019-01-17   NaN    NaN    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
data['Age'] = data['Age'].fillna(data['Age'].mode()[0])

# %%
data.columns
# Out:
# Index(['Date', 'Age', 'Sales', 'Day'], dtype='object')

# %% [markdown]
# If you want to apply it to all the columns of the DataFrame, then

# %%
for column in data.columns:
    data[column].fillna(data[column].mode()[0], inplace=True)

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# **Linear interpolation** is a better technique for measure column, Sale on 2019-01-03 has 8 which is in between 9 and 7

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
#interpolate-A better guess(It uses linear interpolation and comes up with values)
#bydefault it is linear interpolation
new_data=data.interpolate(method='ffill')
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# # Replace the all NaN value in the data frame with -99 value

# %%
import numpy as np

# %%
# will replace NaN value in dataframe with value -99   
new_data = data.replace(to_replace = np.nan, value = -99)
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# Dropping missing values using dropna() </br>
# Drop the complete row if any single column has na value </br>
# Now we drop rows with at least one NaN value (Null value)

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
#Drop missing value with NA(drop a complete row if it has one single na in row)
new_data=data.dropna(how='all')
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# Now we drop a rows whose all data is missing or contain null values(NaN)

# %% [markdown]
# Only drop row if all the value in row has NaN values, using how parameter

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
#Drop missing value with NA only when all the value in a row has na
#how parameter
new_data=data.dropna(how='all')
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# # Dropping Rows with at least 1 null value in CSV file

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
# making new data frame with dropped NA values  
new_data = data.dropna(axis = 0, how ='any') 
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# # Now we drop columns which have at least 1 missing values

# %%
data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %%
# using dropna() function      
new_data = data.dropna(axis = 1, how='all') 
new_data
# Out:
#         Date   Age  Sales        Day
# 0 2019-01-01  32.0    6.0     Monday
# 1 2019-01-02  32.0    9.0    Tuesday
# 2 2019-01-10  28.0    6.0  Wednesday
# 3 2019-01-11  32.0    7.0    Tuesday
# 4 2019-01-12  32.0    6.0     Monday
# 5 2019-01-16  32.0    6.0    Tuesday
# 6 2019-01-17  32.0    6.0    Tuesday
# 7 2019-01-20  34.0    8.0   Thrusday
# 8 2019-01-21  40.0   12.0    Tuesday

# %% [markdown]
# # Keep the row if it has any single non NaN value, threshold=1, keep row if it has one valid value one if threshold = 2, it will keep if there are 2 valid values

# %%
data.set_index('Date',inplace=True)

# %%
data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02  32.0    9.0    Tuesday
# 2019-01-10  28.0    6.0  Wednesday
# 2019-01-11  32.0    7.0    Tuesday
# 2019-01-12  32.0    6.0     Monday
# 2019-01-16  32.0    6.0    Tuesday
# 2019-01-17  32.0    6.0    Tuesday
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
#Keep the rows if it has any non na value
#thershlod parameter(We need one valid value in order to keep the row)
#thresh=N requires that a column has at least N non-NaNs to survive
new_data=data.dropna(thresh=1)
new_data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02  32.0    9.0    Tuesday
# 2019-01-10  28.0    6.0  Wednesday
# 2019-01-11  32.0    7.0    Tuesday
# 2019-01-12  32.0    6.0     Monday
# 2019-01-16  32.0    6.0    Tuesday
# 2019-01-17  32.0    6.0    Tuesday
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
#We want 2 valid(non na) value in order to keep the row
new_data=data.dropna(thresh=2)
new_data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02  32.0    9.0    Tuesday
# 2019-01-10  28.0    6.0  Wednesday
# 2019-01-11  32.0    7.0    Tuesday
# 2019-01-12  32.0    6.0     Monday
# 2019-01-16  32.0    6.0    Tuesday
# 2019-01-17  32.0    6.0    Tuesday
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02  32.0    9.0    Tuesday
# 2019-01-10  28.0    6.0  Wednesday
# 2019-01-11  32.0    7.0    Tuesday
# 2019-01-12  32.0    6.0     Monday
# 2019-01-16  32.0    6.0    Tuesday
# 2019-01-17  32.0    6.0    Tuesday
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
new_data=data.dropna(thresh=3)
new_data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02  32.0    9.0    Tuesday
# 2019-01-10  28.0    6.0  Wednesday
# 2019-01-11  32.0    7.0    Tuesday
# 2019-01-12  32.0    6.0     Monday
# 2019-01-16  32.0    6.0    Tuesday
# 2019-01-17  32.0    6.0    Tuesday
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
new_file = new_data.to_csv("new_file.csv")

# %%
data
# Out:
#              Age  Sales        Day
# Date
# 2019-01-01  32.0    6.0     Monday
# 2019-01-02  32.0    9.0    Tuesday
# 2019-01-10  28.0    6.0  Wednesday
# 2019-01-11  32.0    7.0    Tuesday
# 2019-01-12  32.0    6.0     Monday
# 2019-01-16  32.0    6.0    Tuesday
# 2019-01-17  32.0    6.0    Tuesday
# 2019-01-20  34.0    8.0   Thrusday
# 2019-01-21  40.0   12.0    Tuesday

# %%
data.to_excel("new_xl_file.xlsx")
